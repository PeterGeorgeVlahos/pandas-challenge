# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(25)
# Out:
#     Student ID        student_name gender grade        school_name  \
# 0            0        Paul Bradley      M   9th  Huang High School
# 1            1        Victor Smith      M  12th  Huang High School
# 2            2     Kevin Rodriguez      M  12th  Huang High School
# 3            3   Dr. Richard Scott      M  12th  Huang High School
# 4            4          Bonnie Ray      F   9th  Huang High School
# 5            5       Bryan Miranda      M   9th  Huang High School
# 6            6       Sheena Carter      F  11th  Huang High School
# 7            7        Nicole Baker      F  12th  Huang High School
# 8            8        Michael Roth      M  10th  Huang High School
# 9            9      Matthew Greene      M  10th  Huang High School
# 10          10    Andrew Alexander      M  10th  Huang High School
# 11          11       Daniel Cooper      M  10th  Huang High School
# 12          12     Brittney Walker      F   9th  Huang High School
# ...

# %%
school_data_complete = school_data_complete.copy()

# %%
#number of schools
number_of_schools = len(school_data_complete['school_name'].unique())
number_of_schools
# Out:
# 15

# %%
#total number of students
total_number_of_students = school_data_complete['student_name'].count()
#39170

# %%
#Total Budget
total_district_budget = school_data['budget'].sum()
#24649428

# %%
#Average Math Score
average_district_math_score = school_data_complete['math_score'].mean()
average_district_math_score
# Out:
# 78.98537145774827

# %%
#Average Reading Score
average_district_reading_score = school_data_complete['reading_score'].mean()
average_district_reading_score
# Out:
# 81.87784018381414

# %%
total_students_pass_math = school_data_complete.loc[(school_data_complete['math_score']>=70)].count()["student_name"]
total_students_pass_math = total_students_pass_math

# %%
passing_math_percentage = total_students_pass_math/float(total_number_of_students)*100
passing_math_percentage = passing_math_percentage

# %%
students_pass_reading = school_data_complete[school_data_complete['reading_score']>=70].count()['student_name']

passing_reading_percentage = students_pass_reading/float(total_number_of_students)*100
passing_reading_percentage = passing_reading_percentage

# %%
#% passing both -> Group By Function NOPE -> conditional AND df['A'] & df[B] 
students_pass_math_reading = school_data_complete[(school_data_complete['math_score']>=70) & (school_data_complete['reading_score']>=70)].count()['student_name']
#25528
passing_math_reading_percentage = students_pass_math_reading/float(total_number_of_students)*100
passing_math_reading_percentage = passing_math_reading_percentage

# %%
district_summary_df = pd.DataFrame({'Total Schools': number_of_schools, 'Total Students':[total_number_of_students],
                                          'Total Budget':[total_district_budget], 'Average Math Score':[average_district_math_score],
                                           'Average Reading Score': [average_district_reading_score],'% Passing Math': passing_math_percentage,
                                             '% Passing Reading': passing_reading_percentage, '% Passing Both Math & Reading':passing_math_reading_percentage })
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Passing Both Math & Reading
# 0                      65.172326

# %%
schools_grouped = school_data_complete.groupby(['school_name'])
schools_grouped.count()
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
number_of_students_per_school = schools_grouped['Student ID'].count()
number_of_students_per_school
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
average_math_score_per_school = schools_grouped['math_score'].mean()
average_math_score_per_school
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
average_reading_score_per_school = schools_grouped['reading_score'].mean()
average_reading_score_per_school
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
school_budget = schools_grouped['budget'].mean()

# %%
budget_per_student_per_school = schools_grouped['budget'].mean()/schools_grouped['student_name'].count()
budget_per_student_per_school
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
stu_pass_math = school_data_complete.loc[(school_data_complete['math_score']>=70)]
stu_pass_math.head()
# Out:
#    Student ID   student_name gender grade        school_name  reading_score  \
# 0           0   Paul Bradley      M   9th  Huang High School             66
# 4           4     Bonnie Ray      F   9th  Huang High School             97
# 5           5  Bryan Miranda      M   9th  Huang High School             94
# 6           6  Sheena Carter      F  11th  Huang High School             82
# 8           8   Michael Roth      M  10th  Huang High School             95
#
#    math_score  School ID      type  size   budget
# 0          79          0  District  2917  1910635
# 4          84          0  District  2917  1910635
# 5          94          0  District  2917  1910635
# 6          80          0  District  2917  1910635
# 8          87          0  District  2917  1910635

# %%
stu_pass_math_per_school = stu_pass_math.groupby('school_name')
stu_pass_math_per_school = stu_pass_math_per_school['Student ID'].count()
perct_stu_pass_math_per_school = (stu_pass_math_per_school/number_of_students_per_school)*100
perct_stu_pass_math_per_school
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: Student ID, dtype: float64

# %%
stu_pass_reading = school_data_complete[school_data_complete['reading_score']>=70]
stu_pass_reading.head()
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
#
#    math_score  School ID      type  size   budget
# 1          61          0  District  2917  1910635
# 2          60          0  District  2917  1910635
# 4          84          0  District  2917  1910635
# 5          94          0  District  2917  1910635
# 6          80          0  District  2917  1910635

# %%
stu_pass_reading_per_school = stu_pass_reading.groupby('school_name')
stu_pass_reading_per_school = stu_pass_reading_per_school['Student ID'].count()
perct_stu_pass_reading_per_school = (stu_pass_reading_per_school/number_of_students_per_school )*100
perct_stu_pass_reading_per_school
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: Student ID, dtype: float64

# %%
stu_pass_math_read_per_school = school_data_complete[(school_data_complete['math_score']>=70) & (school_data_complete['reading_score']>=70)]
stu_pass_math_read_per_school = stu_pass_math_read_per_school.groupby('school_name')
stu_pass_math_read_per_school = stu_pass_math_read_per_school['Student ID'].count()
perct_stu_pass_math_read_per_school = (stu_pass_math_read_per_school / number_of_students_per_school) * 100
perct_stu_pass_math_read_per_school
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: Student ID, dtype: float64

# %%
type_school = schools_grouped['type'].unique()
type_school = type_school.explode()
type_school
# Out:
# school_name
# Bailey High School       District
# Cabrera High School       Charter
# Figueroa High School     District
# Ford High School         District
# Griffin High School       Charter
# Hernandez High School    District
# Holden High School        Charter
# Huang High School        District
# Johnson High School      District
# Pena High School          Charter
# Rodriguez High School    District
# Shelton High School       Charter
# Thomas High School        Charter
# Wilson High School        Charter
# Wright High School        Charter
# Name: type, dtype: object

# %%
school_summary_df = pd.DataFrame({'Type': type_school, 'Total Students':number_of_students_per_school,
                                 'Total School Budget':school_budget, 
                                  'Per Student Budget': budget_per_student_per_school,
                                 'Average Math Score': average_math_score_per_school, 
                                    'Average Reading Score': average_reading_score_per_school,
                                 '% Passing Math': perct_stu_pass_math_per_school, 
                                  '% Passing Reading': perct_stu_pass_reading_per_school,
                                 '% Overall Passing': perct_stu_pass_math_read_per_school})
school_summary_df.reset_index(inplace=True)
school_summary_df
# Out:
#               school_name      Type  Total Students  Total School Budget  \
# 0      Bailey High School  District            4976              3124928
# 1     Cabrera High School   Charter            1858              1081356
# 2    Figueroa High School  District            2949              1884411
# 3        Ford High School  District            2739              1763916
# 4     Griffin High School   Charter            1468               917500
# 5   Hernandez High School  District            4635              3022020
# 6      Holden High School   Charter             427               248087
# 7       Huang High School  District            2917              1910635
# 8     Johnson High School  District            4761              3094650
# 9        Pena High School   Charter             962               585858
# 10  Rodriguez High School  District            3999              2547363
# 11    Shelton High School   Charter            1761              1056600
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
school_summary_df.sort_values(by=['% Overall Passing'], ascending=False).head(5)
# Out:
#             school_name     Type  Total Students  Total School Budget  \
# 1   Cabrera High School  Charter            1858              1081356
# 12   Thomas High School  Charter            1635              1043130
# 4   Griffin High School  Charter            1468               917500
# 13   Wilson High School  Charter            2283              1319574
# 9      Pena High School  Charter             962               585858
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 1                582.0           83.061895              83.975780
# 12               638.0           83.418349              83.848930
# 4                625.0           83.351499              83.816757
# 13               578.0           83.274201              83.989488
# 9                609.0           83.839917              84.044699
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 1        94.133477          97.039828          91.334769
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
school_summary_df.sort_values(by=['% Overall Passing']).head(5)
# Out:
#               school_name      Type  Total Students  Total School Budget  \
# 10  Rodriguez High School  District            3999              2547363
# 2    Figueroa High School  District            2949              1884411
# 7       Huang High School  District            2917              1910635
# 5   Hernandez High School  District            4635              3022020
# 8     Johnson High School  District            4761              3094650
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 10               637.0           76.842711              80.744686
# 2                639.0           76.711767              81.158020
# 7                655.0           76.629414              81.182722
# 5                652.0           77.289752              80.934412
# 8                650.0           77.072464              80.966394
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 10       66.366592          80.220055          52.988247
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.head(1)
# Out:
#    Student ID  student_name gender grade        school_name  reading_score  \
# 0           0  Paul Bradley      M   9th  Huang High School             66
#
#    math_score  School ID      type  size   budget
# 0          79          0  District  2917  1910635

# %%
grade_nineth_math = school_data_complete[(school_data_complete['grade'] == '9th')]
nineth_grade_math_grouped = grade_nineth_math.groupby(['school_name']) 
nineth_grade_math_grouped['math_score'].mean()
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School       83.590022
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
grade_tenth_math = school_data_complete[(school_data_complete['grade'] == '10th')]
tenth_grade_math_grouped = grade_tenth_math.groupby(['school_name']) 
tenth_grade_math_grouped['math_score'].mean()
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
grade_elve_math = school_data_complete[(school_data_complete['grade'] == '11th')]
elve_grade_math_grouped = grade_elve_math.groupby(['school_name']) 
elve_grade_math_grouped['math_score'].mean()
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
grade_twelv_math = school_data_complete[(school_data_complete['grade'] == '12th')]
twelv_grade_math_grouped = grade_twelv_math.groupby(['school_name']) 
twelv_grade_math_grouped['math_score'].mean()
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %%
math_score_per_grade_df = pd.DataFrame({'9th Grade Ave Math Score':nineth_grade_math_grouped['math_score'].mean(),
                           '10th Grade Ave Math Score':tenth_grade_math_grouped['math_score'].mean(),
                           '11th Grade Ave Math Score':elve_grade_math_grouped['math_score'].mean(),
                           '12th Grade Ave Math Score':twelv_grade_math_grouped['math_score'].mean()})
math_score_per_grade_df.reset_index(inplace=True)
math_score_per_grade_df
# Out:
#               school_name  9th Grade Ave Math Score  \
# 0      Bailey High School                 77.083676
# 1     Cabrera High School                 83.094697
# 2    Figueroa High School                 76.403037
# 3        Ford High School                 77.361345
# 4     Griffin High School                 82.044010
# 5   Hernandez High School                 77.438495
# 6      Holden High School                 83.787402
# 7       Huang High School                 77.027251
# 8     Johnson High School                 77.187857
# 9        Pena High School                 83.625455
# 10  Rodriguez High School                 76.859966
# 11    Shelton High School                 83.420755
# 12     Thomas High School                 83.590022
# 13     Wilson High School                 83.085578
# 14     Wright High School                 83.264706
#
#     10th Grade Ave Math Score  11th Grade Ave Math Score  \
# 0                   76.996772                  77.515588
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
nineth_grade = school_data_complete[(school_data_complete['grade'] == '9th')]
nineth_grade_read_grouped = nineth_grade.groupby(['school_name']) 
nineth_grade_read_grouped['reading_score'].mean()
# Out:
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136
# Figueroa High School     81.198598
# Ford High School         80.632653
# Griffin High School      83.369193
# Hernandez High School    80.866860
# Holden High School       83.677165
# Huang High School        81.290284
# Johnson High School      81.260714
# Pena High School         83.807273
# Rodriguez High School    80.993127
# Shelton High School      84.122642
# Thomas High School       83.728850
# Wilson High School       83.939778
# Wright High School       83.833333
# Name: reading_score, dtype: float64

# %%
grade_tenth = school_data_complete[(school_data_complete['grade'] == '10th')]
tenth_grade_read_grouped = grade_tenth.groupby(['school_name']) 
tenth_grade_read_grouped['reading_score'].mean()
# Out:
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219
# Figueroa High School     81.408912
# Ford High School         81.262712
# Griffin High School      83.706897
# Hernandez High School    80.660147
# Holden High School       83.324561
# Huang High School        81.512386
# Johnson High School      80.773431
# Pena High School         83.612000
# Rodriguez High School    80.629808
# Shelton High School      83.441964
# Thomas High School       84.254157
# Wilson High School       84.021452
# Wright High School       83.812757
# Name: reading_score, dtype: float64

# %%
grade_elveth = school_data_complete[(school_data_complete['grade'] == '11th')]
elveth_grade_read_grouped = grade_elveth.groupby(['school_name']) 
elveth_grade_read_grouped['reading_score'].mean()
# Out:
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382
# Figueroa High School     80.640339
# Ford High School         80.403642
# Griffin High School      84.288089
# Hernandez High School    81.396140
# Holden High School       83.815534
# Huang High School        81.417476
# Johnson High School      80.616027
# Pena High School         84.335938
# Rodriguez High School    80.864811
# Shelton High School      84.373786
# Thomas High School       83.585542
# Wilson High School       83.764608
# Wright High School       84.156322
# Name: reading_score, dtype: float64

# %%
grade_twelth = school_data_complete[(school_data_complete['grade'] == '12th')]
twelth_grade_read_grouped = grade_twelth.groupby(['school_name']) 
twelth_grade_read_grouped['reading_score'].mean()
# Out:
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958
# Figueroa High School     81.384863
# Ford High School         80.662338
# Griffin High School      84.013699
# Hernandez High School    80.857143
# Holden High School       84.698795
# Huang High School        80.305983
# Johnson High School      81.227564
# Pena High School         84.591160
# Rodriguez High School    80.376426
# Shelton High School      82.781671
# Thomas High School       83.831361
# Wilson High School       84.317673
# Wright High School       84.073171
# Name: reading_score, dtype: float64

# %%
read_score_per_grade_df = pd.DataFrame({'9th Grade Ave Reading Score':nineth_grade_read_grouped['reading_score'].mean(),
                           '10th Grade Ave Reading Score':tenth_grade_read_grouped['reading_score'].mean(),
                           '11th Grade Ave Reading Score':elveth_grade_read_grouped['reading_score'].mean(),
                           '12th Grade Ave Reading Score':twelth_grade_read_grouped['reading_score'].mean()})
read_score_per_grade_df.reset_index(inplace=True)
read_score_per_grade_df
# Out:
#               school_name  9th Grade Ave Reading Score  \
# 0      Bailey High School                    81.303155
# 1     Cabrera High School                    83.676136
# 2    Figueroa High School                    81.198598
# 3        Ford High School                    80.632653
# 4     Griffin High School                    83.369193
# 5   Hernandez High School                    80.866860
# 6      Holden High School                    83.677165
# 7       Huang High School                    81.290284
# 8     Johnson High School                    81.260714
# 9        Pena High School                    83.807273
# 10  Rodriguez High School                    80.993127
# 11    Shelton High School                    84.122642
# 12     Thomas High School                    83.728850
# 13     Wilson High School                    83.939778
# 14     Wright High School                    83.833333
#
#     10th Grade Ave Reading Score  11th Grade Ave Reading Score  \
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_bins = pd.DataFrame({'Per Student Budget': budget_per_student_per_school,
                            'Average Math Score': average_math_score_per_school, 
                            'Average Reading Score': average_reading_score_per_school,
                            '% Passing Math': perct_stu_pass_math_per_school,
                            '% Passing Reading': perct_stu_pass_reading_per_school,
                            '% Overall Passing': perct_stu_pass_math_read_per_school})
school_bins.sort_values(by=['Per Student Budget'])
school_bins.reset_index()
# Out:
#               school_name  Per Student Budget  Average Math Score  \
# 0      Bailey High School               628.0           77.048432
# 1     Cabrera High School               582.0           83.061895
# 2    Figueroa High School               639.0           76.711767
# 3        Ford High School               644.0           77.102592
# 4     Griffin High School               625.0           83.351499
# 5   Hernandez High School               652.0           77.289752
# 6      Holden High School               581.0           83.803279
# 7       Huang High School               655.0           76.629414
# 8     Johnson High School               650.0           77.072464
# 9        Pena High School               609.0           83.839917
# 10  Rodriguez High School               637.0           76.842711
# 11    Shelton High School               600.0           83.359455
# 12     Thomas High School               638.0           83.418349
# ...

# %%
#creating bins for student spending budgets

bins = [0, 584, 629, 645, 675]
labels = ['< $584' , '$585-629', '$630-644', '$645-675' ]

# %%
pd.cut(school_bins['Per Student Budget'], bins, labels=labels).head()
# Out:
# school_name
# Bailey High School      $585-629
# Cabrera High School       < $584
# Figueroa High School    $630-644
# Ford High School        $630-644
# Griffin High School     $585-629
# Name: Per Student Budget, dtype: category
# Categories (4, object): [< $584 < $585-629 < $630-644 < $645-675]

# %%
# Place the data series into a new column inside of the DataFrame
school_bins["Student Budget Range"] = pd.cut(school_bins['Per Student Budget'], bins, labels=labels)
school_bins.drop('Per Student Budget', axis=1,inplace=True)
school_bins.reset_index()
# Out:
#               school_name  Average Math Score  Average Reading Score  \
# 0      Bailey High School           77.048432              81.033963
# 1     Cabrera High School           83.061895              83.975780
# 2    Figueroa High School           76.711767              81.158020
# 3        Ford High School           77.102592              80.746258
# 4     Griffin High School           83.351499              83.816757
# 5   Hernandez High School           77.289752              80.934412
# 6      Holden High School           83.803279              83.814988
# 7       Huang High School           76.629414              81.182722
# 8     Johnson High School           77.072464              80.966394
# 9        Pena High School           83.839917              84.044699
# 10  Rodriguez High School           76.842711              80.744686
# 11    Shelton High School           83.359455              83.725724
# 12     Thomas High School           83.418349              83.848930
# ...

# %%
#[['Per Student Budget','Average Math Score', 'Average Reading Score','% Passing Math','% Passing Reading','% Overall Passing']].
school_bins_grouped = school_bins.groupby('Student Budget Range')
school_bins_grouped.mean()
# Out:
#                       Average Math Score  Average Reading Score  \
# Student Budget Range
# < $584                         83.455399              83.933814
# $585-629                       81.899826              83.155286
# $630-644                       78.518855              81.624473
# $645-675                       76.997210              81.027843
#
#                       % Passing Math  % Passing Reading  % Overall Passing
# Student Budget Range
# < $584                     93.460096          96.610877          90.369459
# $585-629                   87.133538          92.718205          81.418596
# $630-644                   73.484209          84.391793          62.857656
# $645-675                   66.164813          81.133951          53.526855

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
school_summary_df.sort_values(by=['Total Students'])
school_bin_stu_pop = pd.DataFrame({'Total Students': number_of_students_per_school,
                            'Average Math Score': average_math_score_per_school, 
                            'Average Reading Score': average_reading_score_per_school,
                            '% Passing Math': perct_stu_pass_math_per_school,
                            '% Passing Reading': perct_stu_pass_reading_per_school,
                            '% Overall Passing': perct_stu_pass_math_read_per_school})
school_bin_stu_pop
# Out:
#                        Total Students  Average Math Score  \
# school_name
# Bailey High School               4976           77.048432
# Cabrera High School              1858           83.061895
# Figueroa High School             2949           76.711767
# Ford High School                 2739           77.102592
# Griffin High School              1468           83.351499
# Hernandez High School            4635           77.289752
# Holden High School                427           83.803279
# Huang High School                2917           76.629414
# Johnson High School              4761           77.072464
# Pena High School                  962           83.839917
# Rodriguez High School            3999           76.842711
# Shelton High School              1761           83.359455
# Thomas High School               1635           83.418349
# Wilson High School               2283           83.274201
# Wright High School               1800           83.682222
#
# ...

# %%
#creating bins for student population

bins = [0, 999, 1999, 5000]
labels = ['Small (<1000)' , 'Medium (1000-2000)', ' Large (2000-5000) ']

# %%
school_bin_stu_pop["Student Population"] = pd.cut(school_bin_stu_pop['Total Students'], bins, labels=labels)

# %%
school_bin_stu_pop.reset_index()
# Out:
#               school_name  Total Students  Average Math Score  \
# 0      Bailey High School            4976           77.048432
# 1     Cabrera High School            1858           83.061895
# 2    Figueroa High School            2949           76.711767
# 3        Ford High School            2739           77.102592
# 4     Griffin High School            1468           83.351499
# 5   Hernandez High School            4635           77.289752
# 6      Holden High School             427           83.803279
# 7       Huang High School            2917           76.629414
# 8     Johnson High School            4761           77.072464
# 9        Pena High School             962           83.839917
# 10  Rodriguez High School            3999           76.842711
# 11    Shelton High School            1761           83.359455
# 12     Thomas High School            1635           83.418349
# 13     Wilson High School            2283           83.274201
# ...

# %%
#Groupby Student Popultion & their Average scores,
school_stu_size = school_bin_stu_pop.groupby("Student Population").mean()
#Drop Average Student population
school_stu_size.drop('Total Students',axis=1,inplace=True)
#Reset Index and show
school_stu_size = school_stu_size.reset_index()
school_stu_size
# Out:
#     Student Population  Average Math Score  Average Reading Score  \
# 0        Small (<1000)           83.821598              83.929843
# 1   Medium (1000-2000)           83.374684              83.864438
# 2   Large (2000-5000)            77.746417              81.344493
#
#    % Passing Math  % Passing Reading  % Overall Passing
# 0       93.550225          96.099437          89.883853
# 1       93.599695          96.790680          90.621535
# 2       69.963361          82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
school_types_grouped = pd.DataFrame({'School Type': type_school,'Average Math Score': average_math_score_per_school, 
                                    'Average Reading Score': average_reading_score_per_school,
                                 '% Passing Math': perct_stu_pass_math_per_school, 
                                  '% Passing Reading': perct_stu_pass_reading_per_school,
                                 '% Overall Passing': perct_stu_pass_math_read_per_school})
school_types_grouped.reset_index(inplace=True)
school_types_grouped.drop('school_name', axis=1,inplace=True)
school_types_grouped = school_types_grouped.groupby('School Type').mean()
school_types_grouped
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results
